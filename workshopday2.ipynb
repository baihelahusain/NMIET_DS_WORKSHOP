# %% [markdown]
# <a href="https://colab.research.google.com/github/baihelahusain/NMIET_DS_WORKSHOP/blob/main/workshopday2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #sumit abhadas books for Linux commands and many other imp topics

# %%
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0, 5, 11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x, y, 'r') # 'r' is the color red
plt.xlabel('X Axis Title Here')
plt.ylabel('Y Axis Title Here')
plt.title('String Title Here')
plt.show()

# %%
# plt.subplot(nrows, ncols, plot_number)
plt.subplot(1,2,1)
plt.plot(x, y, 'r--') # More on color options later
plt.subplot(1,2,2)
plt.plot(y, x, 'g*-');

# %%
# Create Figure (empty canvas)
fig = plt.figure()

# Add set of axes to figure
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # left, bottom, width, height (range 0 to 1)

# Plot on that set of axes
axes.plot(x, y, 'b')
axes.set_xlabel('Set X Label') # Notice the use of set_ to begin methods
axes.set_ylabel('Set y Label')
axes.set_title('Set Title')
# Out:
# Text(0.5, 1.0, 'Set Title')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3]) # inset axes

# Larger Figure Axes 1
axes1.plot(x, y, 'b')
axes1.set_xlabel('X_label_axes2')
axes1.set_ylabel('Y_label_axes2')
axes1.set_title('Axes 2 Title')

# Insert Figure Axes 2
axes2.plot(y, x, 'r')
axes2.set_xlabel('X_label_axes2')
axes2.set_ylabel('Y_label_axes2')
axes2.set_title('Axes 2 Title');

# %%
fig, axes = plt.subplots()

# Now use the axes object to add stuff to plot
axes.plot(x, y, 'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title')
# Out:
# Text(0.5, 1.0, 'title')

# %%
# Empty canvas of 1 by 2 subplots
fig, axes = plt.subplots(nrows=1, ncols=3)

# %%
for ax in axes:
    ax.plot(x, y, 'b')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_title('title')

# Display the figure object
fig

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

for ax in axes:
    ax.plot(x, y, 'g')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_title('title')

fig
plt.tight_layout()

# %%
fig = plt.figure(figsize=(8,4), dpi=100)

# %%
fig, axes = plt.subplots(figsize=(1,3))

axes.plot(x, y, 'b')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('Huiiiyaaah')
# Out:
# Text(0.5, 1.0, 'Huiiiyaaah')

# %%
import pandas as pd

# %%
d1 = [11,12,13,14,15]
d2 = ['a','b','c','d','e']
d3 = (501,502,503,504,505)
d4 = {'p':1001,'q':1002,'r':1003,'s':1004,'t':1005}

# %%
pd.DataFrame(d1)
# Out:
#     0
# 0  11
# 1  12
# 2  13
# 3  14
# 4  15

# %%
pd.Series(d2,d1)
# Out:
# 11    a
# 12    b
# 13    c
# 14    d
# 15    e
# dtype: object

# %%
d5 = list(d4.values())
d5
# Out:
# [1001, 1002, 1003, 1004, 1005]

# %%
d6 = list(d4.keys())
d6
# Out:
# ['p', 'q', 'r', 's', 't']

# %%
pd.Series(d4)
# Out:
# p    1001
# q    1002
# r    1003
# s    1004
# t    1005
# dtype: int64

# %%
pd.Series(d4,d1)
# Out:
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# dtype: float64

# %%
ser1 = pd.Series([10,20,30,40,50],['q','q','r','s','t'])
ser2 = pd.Series([10,20,30,40,50],['q','q','r','w','t'])

# %%
ser = ser1 + ser2

# %%
pd.DataFrame(ser)
# Out:
#        0
# q   20.0
# q   30.0
# q   30.0
# q   40.0
# r   60.0
# s    NaN
# t  100.0
# w    NaN

# %%
data = pd.DataFrame(np.random.randn(5,4),['a','b','c','d','e'],['w','x','y','z'])
data
# Out:
#           w         x         y         z
# a -0.830778  0.776632 -1.050065 -2.089009
# b  1.500575  0.115375 -2.277345 -1.318243
# c -0.126515 -0.086703 -1.387291  0.015183
# d  0.439268  0.545639 -0.252385 -1.104387
# e  0.142411  0.160720 -1.566268  0.433994

# %%
data['w']
# Out:
# a   -0.830778
# b    1.500575
# c   -0.126515
# d    0.439268
# e    0.142411
# Name: w, dtype: float64

# %%
data[['w','x']]
# Out:
#           w         x
# a -0.830778  0.776632
# b  1.500575  0.115375
# c -0.126515 -0.086703
# d  0.439268  0.545639
# e  0.142411  0.160720

# %%
data['w']>0.32
# Out:
# a    False
# b     True
# c    False
# d     True
# e    False
# Name: w, dtype: bool

# %%
data[1:3]
# Out:
#           w         x         y         z
# b  1.500575  0.115375 -2.277345 -1.318243
# c -0.126515 -0.086703 -1.387291  0.015183

# %%
data.loc['b']
# Out:
# w    1.500575
# x    0.115375
# y   -2.277345
# z   -1.318243
# Name: b, dtype: float64

# %%
data.iloc[0]
# Out:
# w   -0.830778
# x    0.776632
# y   -1.050065
# z   -2.089009
# Name: a, dtype: float64

# %%
data.iloc[3,2]
# Out:
# np.float64(-0.25238507026229884)

# %%
data['x+y']=data['x']+data['y']

# %%
data
# Out:
#           w         x         y         z       x+y
# a -0.830778  0.776632 -1.050065 -2.089009 -0.273433
# b  1.500575  0.115375 -2.277345 -1.318243 -2.161970
# c -0.126515 -0.086703 -1.387291  0.015183 -1.473994
# d  0.439268  0.545639 -0.252385 -1.104387  0.293254
# e  0.142411  0.160720 -1.566268  0.433994 -1.405547

# %%
data.columns
# Out:
# Index(['w', 'x', 'y', 'z', 'x+y'], dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, a to e
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   w       5 non-null      float64
#  1   x       5 non-null      float64
#  2   y       5 non-null      float64
#  3   z       5 non-null      float64
#  4   x+y     5 non-null      float64
# dtypes: float64(5)
# memory usage: 412.0+ bytes

# %%
ndata=data.drop('x+y',axis = 1)

# %%
ndata
# Out:
#           w         x         y         z
# a -0.830778  0.776632 -1.050065 -2.089009
# b  1.500575  0.115375 -2.277345 -1.318243
# c -0.126515 -0.086703 -1.387291  0.015183
# d  0.439268  0.545639 -0.252385 -1.104387
# e  0.142411  0.160720 -1.566268  0.433994

# %%
data
# Out:
#           w         x         y         z       x+y
# a -0.830778  0.776632 -1.050065 -2.089009 -0.273433
# b  1.500575  0.115375 -2.277345 -1.318243 -2.161970
# c -0.126515 -0.086703 -1.387291  0.015183 -1.473994
# d  0.439268  0.545639 -0.252385 -1.104387  0.293254
# e  0.142411  0.160720 -1.566268  0.433994 -1.405547

# %%
data.drop('x+y',axis = 1, inplace = True)

# %%
data
# Out:
#           w         x         y         z
# a -0.830778  0.776632 -1.050065 -2.089009
# b  1.500575  0.115375 -2.277345 -1.318243
# c -0.126515 -0.086703 -1.387291  0.015183
# d  0.439268  0.545639 -0.252385 -1.104387
# e  0.142411  0.160720 -1.566268  0.433994

# %%
data['city']=['pune','mumbai','delhi','hyderabad','bangalore']

# %%
data
# Out:
#           w         x         y         z       city
# a -0.830778  0.776632 -1.050065 -2.089009       pune
# b  1.500575  0.115375 -2.277345 -1.318243     mumbai
# c -0.126515 -0.086703 -1.387291  0.015183      delhi
# d  0.439268  0.545639 -0.252385 -1.104387  hyderabad
# e  0.142411  0.160720 -1.566268  0.433994  bangalore

# %%
data.set_index('city',inplace = True)

# %%
data
# Out:
#                   w         x         y         z
# city
# pune      -0.830778  0.776632 -1.050065 -2.089009
# mumbai     1.500575  0.115375 -2.277345 -1.318243
# delhi     -0.126515 -0.086703 -1.387291  0.015183
# hyderabad  0.439268  0.545639 -0.252385 -1.104387
# bangalore  0.142411  0.160720 -1.566268  0.433994

# %%
data1 = pd.read_csv("/content/Excel_Sample.csv")
data1
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
data2 = pd.read_csv('/content/example')
data2
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
data1.to_csv("H")

# %%
df2 = pd.read_html("https://www.fdic.gov/bank-failures/failed-bank-list")
df2[0]
# Out:
#                                Bank Name               City         State  \
# 0                   Pulaski Savings Bank            Chicago      Illinois
# 1     The First National Bank of Lindsay            Lindsay      Oklahoma
# 2  Republic First Bank dba Republic Bank       Philadelphia  Pennsylvania
# 3                          Citizens Bank           Sac City          Iowa
# 4               Heartland Tri-State Bank            Elkhart        Kansas
# 5                    First Republic Bank      San Francisco    California
# 6                         Signature Bank           New York      New York
# 7                    Silicon Valley Bank        Santa Clara    California
# 8                      Almena State Bank             Almena        Kansas
# 9             First City Bank of Florida  Fort Walton Beach       Florida
#
#     Cert                Acquiring Institution      Closing Date  \
# 0  28611                      Millennium Bank  January 17, 2025
# ...

# %%
type(df2)
# Out:
# list

# %%
d = (90)
type(d)
# Out:
# int

# %%
c = (d,)#This comma called tail comma use for making an integer to tuple
type(c)
# Out:
# tuple

# %%
e = {}
type(e)
# Out:
# dict
